# %% [markdown]
# ## MASTER DATA SCIENCE: NUCLIO
# ### PROFESOR: JOSEPH GALLART
# ### PROJECT TRENMAX 2/2
# ### Silvia, Wesley, Daniela

# %%
#IMPORTAMOS LAS LIBRERÍAS

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder,MinMaxScaler

import folium
import plotly.express as px

# %%
#LEER EL ARCHIVO PICKLE
df_renfe_recuperado=pd.read_pickle("df_renfe_clean.pkl")

# %%
df_renfe_recuperado.head()
# Out:
#   CIUDAD_ORIGEN CIUDAD_DESTINO TIPO_TREN TIPO_TARIFA    CLASE  PRECIO  \
# 0       SEVILLA         MADRID     ALVIA    Flexible  Turista   67.20
# 1     BARCELONA         MADRID       AVE    Flexible  Turista  107.70
# 2       SEVILLA         MADRID       AVE       Promo  Turista   47.30
# 3      VALENCIA         MADRID  REGIONAL  Adulto ida  Turista   28.35
# 4        MADRID      BARCELONA   AVE-TGV       Promo  Turista   66.75
#
#    TIEMPO_VIAJE   DIF_INI_BUS  FECHA_CONSULTA_HORA FECHA_CONSULTA_NOMBREDIA  \
# 0         158.0  50092.950000                    1                 Saturday
# 1         190.0  31494.816667                   13                 Saturday
# 2         150.0  52275.950000                    6                Wednesday
# 3         460.0  26968.016667                   21                   Friday
# 4         179.0  68741.383333                   19                 Thursday
#
#    ...  FECHA_CONSULTA_MES  FECHA_INICIO_HORA  FECHA_INICIO_NOMBREDIA  \
# 0  ...                   5                 20                  Friday
# 1  ...                   6                 10                  Sunday
# 2  ...                   4                 13                Thursday
# 3  ...                   5                 14               Wednesday
# 4  ...                   5                 13               Wednesday
#
#   FECHA_INICIO_DIA  FECHA_INICIO_MES  FECHA_FIN_HORA  FECHA_FIN_NOMBREDIA  \
# 0               28                 6              23               Friday
# 1               14                 7              13               Sunday
# 2               23                 5              16             Thursday
# 3               29                 5              22            Wednesday
# 4               26                 6              16            Wednesday
#
#   FECHA_FIN_DIA  FECHA_FIN_MES              RUTA
# 0            28              6    SEVILLA MADRID
# 1            14              7  BARCELONA MADRID
# 2            23              5    SEVILLA MADRID
# 3            29              5   VALENCIA MADRID
# 4            26              6  MADRID BARCELONA
#
# [5 rows x 21 columns]

# %% [markdown]
# ### PREGUNTA 1
# ##### Hola Juan, nuevamente Pedro por aquí, luego de hacer el análisis vamos a preparar nuestro dataset para hacer el modelo, para ello vamos a importar el dataset que está en un pickle, luego de ello por favor dime si hay variables correlacionadas, de ser así elimínalas por favor.
#
# R: 'FECHA_INICIO_DIA' con 'FECHA_FIN_DIA' y 'FECHA_INICIO_MES' con 'FECHA_FIN_MES'

# %%
corr = df_renfe_recuperado.corr(numeric_only=True)

# %%
corr.style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_e1676_row0_col0, #T_e1676_row1_col1, #T_e1676_row2_col2, #T_e1676_row3_col3, #T_e1676_row4_col4, #T_e1676_row5_col5, #T_e1676_row6_col6, #T_e1676_row7_col7, #T_e1676_row7_col10, #T_e1676_row8_col8, #T_e1676_row8_col11, #T_e1676_row9_col9, #T_e1676_row10_col7, #T_e1676_row10_col10, #T_e1676_row11_col8, #T_e1676_row11_col11 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_e1676_row0_col1, #T_e1676_row0_col2, #T_e1676_row0_col9, #T_e1676_row1_col3, #T_e1676_row1_col6, #T_e1676_row2_col0, #T_e1676_row4_col3, #T_e1676_row4_col5, #T_e1676_row5_col4, #T_e1676_row7_col3, #T_e1676_row7_col8, #T_e1676_row7_col11, #T_e1676_row8_col7, #T_e1676_row8_col10, #T_e1676_row10_col3, #T_e1676_row10_col8, #T_e1676_row10_col11, #T_e1676_row11_col7, #T_e1676_row11_col10 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_e1676_row0_col3, #T_e1676_row2_col3 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_e1676_row0_col4, #T_e1676_row1_col4, #T_e1676_row3_col4, #T_e1676_row7_col4, #T_e1676_row9_col5, #T_e1676_row10_col4 {
#   background-color: #fdd6ae;
#   color: #000000;
# }
# #T_e1676_row0_col5 {
#   background-color: #fee3c8;
#   color: #000000;
# }
# #T_e1676_row0_col6, #T_e1676_row1_col8, #T_e1676_row1_col11, #T_e1676_row3_col7, #T_e1676_row3_col10, #T_e1676_row4_col7, #T_e1676_row4_col10, #T_e1676_row6_col8, #T_e1676_row6_col11, #T_e1676_row9_col8, #T_e1676_row9_col11 {
#   background-color: #fdd5ab;
#   color: #000000;
# }
# #T_e1676_row0_col7, #T_e1676_row0_col10 {
#   background-color: #fdd0a2;
#   color: #000000;
# }
# #T_e1676_row0_col8, #T_e1676_row0_col11 {
#   background-color: #feecd9;
#   color: #000000;
# }
# #T_e1676_row1_col0, #T_e1676_row6_col3, #T_e1676_row9_col3 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_e1676_row1_col2 {
#   background-color: #fdd7b1;
#   color: #000000;
# }
# #T_e1676_row1_col5 {
#   background-color: #fdd7af;
#   color: #000000;
# }
# #T_e1676_row1_col7, #T_e1676_row1_col10, #T_e1676_row2_col4, #T_e1676_row6_col4, #T_e1676_row6_col5, #T_e1676_row7_col0, #T_e1676_row9_col4, #T_e1676_row10_col0 {
#   background-color: #fdd5ad;
#   color: #000000;
# }
# #T_e1676_row1_col9, #T_e1676_row5_col7, #T_e1676_row5_col10 {
#   background-color: #fee0c1;
#   color: #000000;
# }
# #T_e1676_row2_col1, #T_e1676_row2_col7, #T_e1676_row2_col10, #T_e1676_row9_col2 {
#   background-color: #fdd8b2;
#   color: #000000;
# }
# #T_e1676_row2_col5 {
#   background-color: #fdc794;
#   color: #000000;
# }
# #T_e1676_row2_col6, #T_e1676_row4_col8, #T_e1676_row4_col11, #T_e1676_row7_col6, #T_e1676_row10_col6 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_e1676_row2_col8, #T_e1676_row2_col11 {
#   background-color: #f67723;
#   color: #f1f1f1;
# }
# #T_e1676_row2_col9 {
#   background-color: #fff0e2;
#   color: #000000;
# }
# #T_e1676_row3_col0, #T_e1676_row3_col2, #T_e1676_row4_col2, #T_e1676_row6_col2 {
#   background-color: #fdd9b5;
#   color: #000000;
# }
# #T_e1676_row3_col1, #T_e1676_row4_col1, #T_e1676_row7_col1, #T_e1676_row10_col1 {
#   background-color: #fedcb9;
#   color: #000000;
# }
# #T_e1676_row3_col5, #T_e1676_row6_col7, #T_e1676_row6_col10, #T_e1676_row9_col7, #T_e1676_row9_col10 {
#   background-color: #fdd4aa;
#   color: #000000;
# }
# #T_e1676_row3_col6, #T_e1676_row4_col6, #T_e1676_row5_col6 {
#   background-color: #fedebd;
#   color: #000000;
# }
# #T_e1676_row3_col8, #T_e1676_row3_col11 {
#   background-color: #fdd2a6;
#   color: #000000;
# }
# #T_e1676_row3_col9, #T_e1676_row4_col9, #T_e1676_row7_col9, #T_e1676_row10_col9 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_e1676_row4_col0 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_e1676_row5_col0 {
#   background-color: #fee7d1;
#   color: #000000;
# }
# #T_e1676_row5_col1 {
#   background-color: #fedcbb;
#   color: #000000;
# }
# #T_e1676_row5_col2 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_e1676_row5_col3 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_e1676_row5_col8, #T_e1676_row5_col11, #T_e1676_row8_col5, #T_e1676_row11_col5 {
#   background-color: #9b3203;
#   color: #f1f1f1;
# }
# #T_e1676_row5_col9, #T_e1676_row8_col9, #T_e1676_row11_col9 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_e1676_row6_col0 {
#   background-color: #fdd1a4;
#   color: #000000;
# }
# #T_e1676_row6_col1 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_e1676_row6_col9 {
#   background-color: #932f03;
#   color: #f1f1f1;
# }
# #T_e1676_row7_col2, #T_e1676_row8_col4, #T_e1676_row8_col6, #T_e1676_row9_col0, #T_e1676_row10_col2, #T_e1676_row11_col4, #T_e1676_row11_col6 {
#   background-color: #fedebf;
#   color: #000000;
# }
# #T_e1676_row7_col5, #T_e1676_row10_col5 {
#   background-color: #fee1c4;
#   color: #000000;
# }
# #T_e1676_row8_col0, #T_e1676_row11_col0 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# #T_e1676_row8_col1, #T_e1676_row11_col1 {
#   background-color: #fddbb8;
#   color: #000000;
# }
# #T_e1676_row8_col2, #T_e1676_row11_col2 {
#   background-color: #f87d29;
#   color: #f1f1f1;
# }
# #T_e1676_row8_col3, #T_e1676_row11_col3 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_e1676_row9_col1 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_e1676_row9_col6 {
#   background-color: #8f2d04;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e1676">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1676_level0_col0" class="col_heading level0 col0" >PRECIO</th>
#       <th id="T_e1676_level0_col1" class="col_heading level0 col1" >TIEMPO_VIAJE</th>
#       <th id="T_e1676_level0_col2" class="col_heading level0 col2" >DIF_INI_BUS</th>
#       <th id="T_e1676_level0_col3" class="col_heading level0 col3" >FECHA_CONSULTA_HORA</th>
#       <th id="T_e1676_level0_col4" class="col_heading level0 col4" >FECHA_CONSULTA_DIA</th>
#       <th id="T_e1676_level0_col5" class="col_heading level0 col5" >FECHA_CONSULTA_MES</th>
#       <th id="T_e1676_level0_col6" class="col_heading level0 col6" >FECHA_INICIO_HORA</th>
#       <th id="T_e1676_level0_col7" class="col_heading level0 col7" >FECHA_INICIO_DIA</th>
#       <th id="T_e1676_level0_col8" class="col_heading level0 col8" >FECHA_INICIO_MES</th>
#       <th id="T_e1676_level0_col9" class="col_heading level0 col9" >FECHA_FIN_HORA</th>
#       <th id="T_e1676_level0_col10" class="col_heading level0 col10" >FECHA_FIN_DIA</th>
#       <th id="T_e1676_level0_col11" class="col_heading level0 col11" >FECHA_FIN_MES</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1676_level0_row0" class="row_heading level0 row0" >PRECIO</th>
#       <td id="T_e1676_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e1676_row0_col1" class="data row0 col1" >-0.234128</td>
#       <td id="T_e1676_row0_col2" class="data row0 col2" >-0.242212</td>
#       <td id="T_e1676_row0_col3" class="data row0 col3" >0.004322</td>
#       <td id="T_e1676_row0_col4" class="data row0 col4" >-0.004429</td>
#       <td id="T_e1676_row0_col5" class="data row0 col5" >-0.101142</td>
#       <td id="T_e1676_row0_col6" class="data row0 col6" >0.062088</td>
#       <td id="T_e1676_row0_col7" class="data row0 col7" >0.033258</td>
#       <td id="T_e1676_row0_col8" class="data row0 col8" >-0.188555</td>
#       <td id="T_e1676_row0_col9" class="data row0 col9" >-0.030274</td>
#       <td id="T_e1676_row0_col10" class="data row0 col10" >0.033258</td>
#       <td id="T_e1676_row0_col11" class="data row0 col11" >-0.188555</td>
#     </tr>
#     <tr>
#       <th id="T_e1676_level0_row1" class="row_heading level0 row1" >TIEMPO_VIAJE</th>
#       <td id="T_e1676_row1_col0" class="data row1 col0" >-0.234128</td>
#       <td id="T_e1676_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e1676_row1_col2" class="data row1 col2" >0.018297</td>
#       <td id="T_e1676_row1_col3" class="data row1 col3" >-0.003846</td>
#       <td id="T_e1676_row1_col4" class="data row1 col4" >-0.004647</td>
#       <td id="T_e1676_row1_col5" class="data row1 col5" >-0.010935</td>
#       <td id="T_e1676_row1_col6" class="data row1 col6" >-0.210673</td>
#       <td id="T_e1676_row1_col7" class="data row1 col7" >-0.007194</td>
#       <td id="T_e1676_row1_col8" class="data row1 col8" >-0.001396</td>
#       <td id="T_e1676_row1_col9" class="data row1 col9"

# %%
# Vemos que FECHA_INICIO_DIA	está 100% relacionada con FECHA_FIN_DIA
# También tenemos FECHA_INICIO_MES con FECHA_FIN_MES
#esto significa que todos los viajes empiezan y terminan el mismo día y por lo tanto empiezan y terminan el mismo mes,
#en esté caso eliminaremos una de las 2 columnas y la otra la renombraremos como FECHA_INI_FIN_MES

# %%
del df_renfe_recuperado['FECHA_FIN_MES']

# %%
df_renfe_recuperado['FECHA_INI_FIN_MES'] = df_renfe_recuperado['FECHA_INICIO_MES']

# %%
del df_renfe_recuperado['FECHA_INICIO_MES']

# %%
del df_renfe_recuperado['FECHA_FIN_DIA']

# %%
df_renfe_recuperado['FECHA_INI_FIN_DIA'] = df_renfe_recuperado['FECHA_INICIO_DIA']

# %%
del df_renfe_recuperado['FECHA_INICIO_DIA']

# %% [markdown]
# ### PREGUNTA 2
# ##### Perfecto Juan (o eso espero) he visto que la distribución del precio tiene una distribución un poco extraña, ¿Me puedes explicar? y ¿Qué podríamos hacer al respecto?
#
# R: Eliminar los outlayers y corregir la distribuciòn aplicando logaritmo base 10.

# %%
df_renfe_recuperado2=df_renfe_recuperado.copy()

# %%
df_renfe_recuperado2['PRECIO'].hist()
# Out:
# <Axes: >

# %%
df_renfe_recuperado2 = df_renfe_recuperado2[df_renfe_recuperado2['PRECIO']<150]

# %%
df_renfe_recuperado2['PRECIO'].hist()
# Out:
# <Axes: >

# %%
df_renfe_recuperado2['LOG_PRECIO']=np.log10(df_renfe_recuperado2['PRECIO'])

# %%
df_renfe_recuperado2['LOG_PRECIO'].hist()
# Out:
# <Axes: >

# %%
#Que si no hubiese tratado los outlayers y sólo se aplica el log:
df_renfe_recuperado['LOG_PRECIO']=np.log10(df_renfe_recuperado['PRECIO'])
df_renfe_recuperado['LOG_PRECIO'].hist()
# Out:
# <Axes: >

# %%
del(df_renfe_recuperado2['PRECIO'])

# %%
df_renfe_recuperado2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 345709 entries, 0 to 383567
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   CIUDAD_ORIGEN             345709 non-null  object
#  1   CIUDAD_DESTINO            345709 non-null  object
#  2   TIPO_TREN                 345709 non-null  object
#  3   TIPO_TARIFA               345709 non-null  object
#  4   CLASE                     345709 non-null  object
#  5   TIEMPO_VIAJE              345709 non-null  float64
#  6   DIF_INI_BUS               345709 non-null  float64
#  7   FECHA_CONSULTA_HORA       345709 non-null  int32
#  8   FECHA_CONSULTA_NOMBREDIA  345709 non-null  object
#  9   FECHA_CONSULTA_DIA        345709 non-null  int32
#  10  FECHA_CONSULTA_MES        345709 non-null  int32
#  11  FECHA_INICIO_HORA         345709 non-null  int32
#  12  FECHA_INICIO_NOMBREDIA    345709 non-null  object
#  13  FECHA_FIN_HORA            345709 non-null  int32
#  14  FECHA_FIN_NOMBREDIA       345709 non-null  object
#  15  RUTA                      345709 non-null  object
#  16  FECHA_INI_FIN_MES         345709 non-null  int32
#  17  FECHA_INI_FIN_DIA         345709 non-null  int32
#  18  LOG_PRECIO                345709 non-null  float64
# dtypes: float64(3), int32(7), object(9)
# memory usage: 43.5+ MB

# %% [markdown]
# ### PREGUNTA 3
# ##### Gracias Juan, vamos a hacer un análisis de cómo se comportan las variables con respecto al precio, como son muchas pon especial atención en el día de inicio del viaje (lunes, martes, miércoles...) vs el precio, ¿Ves alguna relación? (usar violinplot)
#
# R: Podemos ver que los marte y jueves tienen el mayor precio, y los precios más bajos en cambio se encuentran sabados y domingos
# También observamos que donde se concentran más los precios el viernes y domingo ronda los 75€
# el miercoles miercoles, martes y lunes se concentran más sobre los 30
# Y el jueves y sabado los precios se distribuyen más aunque si que es cierto que el jueves tiene precios por lo j¡general más altos que el sabado

# %%
df_renfe_recuperado3 = df_renfe_recuperado2.copy()

# %%
sns.violinplot(x='FECHA_INICIO_NOMBREDIA', y='LOG_PRECIO', linewidth=1,linecolor="k", data=df_renfe_recuperado3)
# Out:
# <Axes: xlabel='FECHA_INICIO_NOMBREDIA', ylabel='LOG_PRECIO'>

# %% [markdown]
# ### PREGUNTA 4
# ##### También podemos hacer un análisis entre el tiempo de viaje y el precio, ¿Ves alguna relación? (usar scatterplot, si demora mucho hacer una muestra del dataset)
#
# R:Parece ser que mientras que los viajes cortos tienen precios de todo tipo,
# los viajes que superan los 210min (3h y media) son más económicos

# %%
df_renfe_recuperado4 = df_renfe_recuperado3.copy()

# %%
sns.scatterplot(x='TIEMPO_VIAJE', y='LOG_PRECIO', s=80, color="blue", marker=".", data=df_renfe_recuperado4);

# %% [markdown]
# ### PREGUNTA 5
# ##### Separemos nuestras variables, entre Listas_Categoricas, Listas_Numericas y Listas_Boolean, antes de eso podemos eliminar algunas columnas que a criterio de negocio podemos eliminar, ¿Cierto? Perfecto! voy a empezar a hacer el tratamiento con las Listas_Categoricas, he decidido aplicar un OneHotEncoding, eso ¿Qué significa? ¿Me lo recuerdas? ¡Vamos a hacerlo!
#
# R: Un OnehotEndcoding coge los valores únicos dentro de una columna categorica
# y con ellos crea nuevas columnas booleanas, con ello conseguimos ver a que
#  categórica pertenece los valores de esa fila
#
# (TIENE ALTERNATIVAS)

# %%
target = ['LOG_PRECIO']
def obtener_lista_variables(dataset):
    lista_num = []
    lista_bool=[]
    lista_cat = []

    for i in dataset:
        if (dataset[i].dtype.kind=='i' or dataset[i].dtype.kind=='f') and\
        len(dataset[i].unique()) != 2 and i not in target:
            lista_num.append(i)

        elif (dataset[i].dtype.kind=='i' or dataset[i].dtype.kind=='f') and \
        len(dataset[i].unique()) == 2 and i not in target:
            lista_bool.append(i)

        elif (dataset[i].dtype.kind=='O') and i not in target:
            lista_cat.append(i)

    return lista_num, lista_bool, lista_cat

# %%
lnum,lbool, lcat = obtener_lista_variables(df_renfe_recuperado4)

# %%
lcat
# Out:
# ['CIUDAD_ORIGEN',
#  'CIUDAD_DESTINO',
#  'TIPO_TREN',
#  'TIPO_TARIFA',
#  'CLASE',
#  'FECHA_CONSULTA_NOMBREDIA',
#  'FECHA_INICIO_NOMBREDIA',
#  'FECHA_FIN_NOMBREDIA',
#  'RUTA']

# %%
df_renfe_recuperado5 = pd.get_dummies(data=df_renfe_recuperado4, columns = lcat)

# %%
df_renfe_recuperado5.head()
# Out:
#    TIEMPO_VIAJE   DIF_INI_BUS  FECHA_CONSULTA_HORA  FECHA_CONSULTA_DIA  \
# 0         158.0  50092.950000                    1                  25
# 1         190.0  31494.816667                   13                  22
# 2         150.0  52275.950000                    6                  17
# 3         460.0  26968.016667                   21                  10
# 4         179.0  68741.383333                   19                   9
#
#    FECHA_CONSULTA_MES  FECHA_INICIO_HORA  FECHA_FIN_HORA  FECHA_INI_FIN_MES  \
# 0                   5                 20              23                  6
# 1                   6                 10              13                  7
# 2                   4                 13              16                  5
# 3                   5                 14              22                  5
# 4                   5                 13              16                  6
#
#    FECHA_INI_FIN_DIA  LOG_PRECIO  ...  FECHA_FIN_NOMBREDIA_Tuesday  \
# 0                 28    1.827369  ...                        False
# 1                 14    2.032216  ...                        False
# 2                 23    1.674861  ...                        False
# 3                 29    1.452553  ...                        False
# 4                 26    1.824451  ...                        False
#
#    FECHA_FIN_NOMBREDIA_Wednesday  RUTA_BARCELONA MADRID  \
# 0                          False                  False
# 1                          False                   True
# 2                          False                  False
# 3                           True                  False
# 4                           True                  False
#
#    RUTA_MADRID BARCELONA  RUTA_MADRID PONFERRADA  RUTA_MADRID SEVILLA  \
# 0                  False                   False                False
# 1                  False                   False                False
# 2                  False                   False                False
# 3                  False                   False                False
# 4                   True                   False                False
#
#    RUTA_MADRID VALENCIA  RUTA_PONFERRADA MADRID  RUTA_SEVILLA MADRID  \
# 0                 False                   False                 True
# 1                 False                   False                False
# 2                 False                   False                 True
# 3                 False                   False                False
# 4                 False                   False                False
#
#    RUTA_VALENCIA MADRID
# 0                 False
# 1                 False
# 2                 False
# 3                  True
# 4                 False
#
# [5 rows x 78 columns]

# %% [markdown]
# ### PREGUNTA 6
# ##### Ahora las Listas_Numericas, un MinMaxScaler iría bien, ¿Qué significa eso?  ¡Vamos a hacerlo!
#
# R: Con un MinMaxScaler transfomamos los valores dentro de una columna númerica
# escalando los valoresd dentro de un rango establecido (por defecto 0-1)
#
# (TIENE ALTERNATIVAS)

# %%
df_renfe_recuperado6 = df_renfe_recuperado5.copy()

# %%
lbool
# Out:
# []

# %%
lnum
# Out:
# ['TIEMPO_VIAJE',
#  'DIF_INI_BUS',
#  'FECHA_CONSULTA_HORA',
#  'FECHA_CONSULTA_DIA',
#  'FECHA_CONSULTA_MES',
#  'FECHA_INICIO_HORA',
#  'FECHA_FIN_HORA',
#  'FECHA_INI_FIN_MES',
#  'FECHA_INI_FIN_DIA']

# %%
minMaxResultado = MinMaxScaler()

# %%
df_renfe_recuperado6[lnum] = minMaxResultado.fit_transform(df_renfe_recuperado6[lnum])

# %%
df_renfe_recuperado6.head()
# Out:
#    TIEMPO_VIAJE  DIF_INI_BUS  FECHA_CONSULTA_HORA  FECHA_CONSULTA_DIA  \
# 0      0.092736     0.582137             0.043478            0.800000
# 1      0.142195     0.365872             0.565217            0.700000
# 2      0.080371     0.607521             0.260870            0.533333
# 3      0.559505     0.313233             0.913043            0.300000
# 4      0.125193     0.798986             0.826087            0.266667
#
#    FECHA_CONSULTA_MES  FECHA_INICIO_HORA  FECHA_FIN_HORA  FECHA_INI_FIN_MES  \
# 0                0.25               0.90        1.000000           0.333333
# 1                0.50               0.40        0.333333           0.500000
# 2                0.00               0.55        0.533333           0.166667
# 3                0.25               0.60        0.933333           0.166667
# 4                0.25               0.55        0.533333           0.333333
#
#    FECHA_INI_FIN_DIA  LOG_PRECIO  ...  FECHA_FIN_NOMBREDIA_Tuesday  \
# 0           0.900000    1.827369  ...                        False
# 1           0.433333    2.032216  ...                        False
# 2           0.733333    1.674861  ...                        False
# 3           0.933333    1.452553  ...                        False
# 4           0.833333    1.824451  ...                        False
#
#    FECHA_FIN_NOMBREDIA_Wednesday  RUTA_BARCELONA MADRID  \
# 0                          False                  False
# 1                          False                   True
# 2                          False                  False
# 3                           True                  False
# 4                           True                  False
#
#    RUTA_MADRID BARCELONA  RUTA_MADRID PONFERRADA  RUTA_MADRID SEVILLA  \
# 0                  False                   False                False
# 1                  False                   False                False
# 2                  False                   False                False
# 3                  False                   False                False
# 4                   True                   False                False
#
#    RUTA_MADRID VALENCIA  RUTA_PONFERRADA MADRID  RUTA_SEVILLA MADRID  \
# 0                 False                   False                 True
# 1                 False                   False                False
# 2                 False                   False                 True
# 3                 False                   False                False
# 4                 False                   False                False
#
#    RUTA_VALENCIA MADRID
# 0                 False
# 1                 False
# 2                 False
# 3                  True
# 4                 False
#
# [5 rows x 78 columns]

# %% [markdown]
# ### PREGUNTA 7
# ##### Genial lo tenemos todo, ahora te voy a ayudar a hacer el modelo (en caso nos de el tiempo!), será tu primer modelo, ¿Verdad? :), cuando terminemos envíame el fichero que has desarrollado, mil gracias!

# %%
df_renfe_recuperado7 = df_renfe_recuperado6.copy()
